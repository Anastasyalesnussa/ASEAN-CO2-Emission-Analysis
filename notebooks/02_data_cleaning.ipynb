# %% [markdown]
# # Data Cleaning

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Load Data
df = pd.read_csv("co2_emission_asean_raw.csv")

df.head()
# Out:
#   Country  Year  Annual CO2 emissions (per capita)
# 0  Brunei  1933                           0.106975
# 1  Brunei  1934                           1.244213
# 2  Brunei  1935                           0.703475
# 3  Brunei  1936                           2.045512
# 4  Brunei  1937                           5.286885

# %%
df.columns = df.columns.str.strip()

# %%
df = df.rename(columns={
    "Country": "country",
    "Year": "year",
    "Annual CO2 emissions (per capita)": "co2_per_capita"
})

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(' ', '_')
              .str.replace('₂', '2')
              .str.replace('__', '_')    
              .str.replace('[()]', '', regex=True)
)

df = df.rename(columns={
    "annual_co2_emissions_per_capita": "co2_per_capita"
})

print(df.columns.tolist())
# Out:
# ['country', 'year', 'co2_per_capita']

# %%
df["year"] = df["year"].astype(int)
df["co2_per_capita"] = pd.to_numeric(df["co2_per_capita"], errors="coerce")

# %%
# Save Clean Dataset
df.to_csv("co2_emission_asean_clean.csv", index=False)
print("Clean dataset saved successfully!")
# Out:
# Clean dataset saved successfully!
